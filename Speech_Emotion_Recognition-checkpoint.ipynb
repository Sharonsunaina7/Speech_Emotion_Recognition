# %%
import keras
from keras.layers import Activation, Dense, Dropout, Conv2D, Flatten, MaxPooling2D, BatchNormalization
from keras.models import Sequential
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from tensorflow.keras.models import load_model
import librosa
import librosa.display
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.1

# %%
os.getcwd()
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'emotion_voice', 'gender_voice', 'gui.py', 'saved models', 'Speech_Emotion_Recognition.ipynb']

# %%
path = os.getcwd()
file_name = 'emotion_voice'
new_path = os.path.join(path, file_name)
os.chdir(new_path)

# %%
path = os.getcwd()
file_name = 'train'
new_path = os.path.join(path, file_name)
os.chdir(new_path)

# %%
path = os.getcwd()
file_name = 'Angry'
new_path = os.path.join(path, file_name)
os.chdir(new_path)

# %%
os.listdir()[777]
# Out:
# '1049_TSI_ANG_XX.wav'

# %%
import IPython.display as ipd
ipd.Audio(os.listdir()[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y,sr = librosa.load(os.listdir()[0], duration=2.97)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 128)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
import librosa
import librosa.display
import os
import matplotlib.pyplot as plt

y, sr = librosa.load(os.listdir()[0], duration=2.97)

plt.figure(figsize=(10, 4))
librosa.display.waveshow(y, sr=sr)
plt.title('Waveform')
plt.show()

# %%
X = librosa.stft(y)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14,5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')

# %%
data_path = 'C:\\Users\\LENOVO\\Desktop\\Voice_Emotion_Detector\\emotion_voice'
emotions = {
    'Neutral': 0,
    'Calm': 1,
    'Happy': 2,
    'Sad': 3,
    'Angry': 4,
    'Fearful': 5,
    'Disgust': 6,
    'Surprise': 7
}

def extract_features(file_path, max_pad_len=174):
    try:
        audio, sample_rate = librosa.load(file_path, res_type='kaiser_fast', duration=2.5, sr=22050, offset=0.5)
        mel_spectrogram = librosa.feature.melspectrogram(y=audio, sr=sample_rate, n_mels=128)
        log_mel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
        if log_mel_spectrogram.shape[1] > max_pad_len:
            log_mel_spectrogram = log_mel_spectrogram[:, :max_pad_len]
        else:
            pad_width = max_pad_len - log_mel_spectrogram.shape[1]
            log_mel_spectrogram = np.pad(log_mel_spectrogram, pad_width=((0, 0), (0, pad_width)), mode='constant')
        return log_mel_spectrogram
    except Exception as e:
        print(f"Error encountered while parsing file: {file_path}\n{e}")
        return None

# %%
def prepare_dataset(data_path, emotions):
    features = []
    labels = []
    audio_extensions = ('.wav', '.mp3', '.flac') 

    for emotion, label in emotions.items():
        emotion_path = os.path.join(data_path, emotion)
        if not os.path.isdir(emotion_path):
            print(f"Directory {emotion_path} not found")
            continue
        for file in os.listdir(emotion_path):
            file_path = os.path.join(emotion_path, file)
            if not file.lower().endswith(audio_extensions):
                print(f"Skipping non-audio file: {file_path}")
                continue
            data = extract_features(file_path)
            if data is not None:
                features.append(data)
                labels.append(label)

    features = np.array(features)
    labels = np.array(labels)
    labels = to_categorical(labels)
    return features, labels

# %%
train_path = os.path.join(data_path, 'train')
test_path = os.path.join(data_path, 'test')

X_train, y_train = prepare_dataset(train_path, emotions)
X_test, y_test = prepare_dataset(test_path, emotions)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
# Out:
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\train\Neutral\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\train\Calm\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\train\Happy\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\train\Sad\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\train\Angry\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\train\Fearful\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\train\Disgust\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\train\Surprise\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\test\Neutral\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\test\Calm\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\test\Happy\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\test\Sad\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\test\Angry\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\test\Fearful\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\test\Disgust\desktop.ini
# Skipping non-audio file: C:\Users\LENOVO\Desktop\Voice_Emotion_Detector\emotion_voice\test\Surprise\desktop.ini

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), padding='same', input_shape=(X_train.shape[1], X_train.shape[2], 1)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, (3, 3), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(len(emotions)))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, batch_size=32, epochs=15, validation_data=(X_test, y_test))
# Out:
# Epoch 1/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 258s 825ms/step - accuracy: 0.3310 - loss: 1.9005 - val_accuracy: 0.3600 - val_loss: 1.6592
# Epoch 2/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 246s 818ms/step - accuracy: 0.4961 - loss: 1.2971 - val_accuracy: 0.3300 - val_loss: 1.8324
# Epoch 3/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 246s 819ms/step - accuracy: 0.5661 - loss: 1.1197 - val_accuracy: 0.4600 - val_loss: 1.7837
# Epoch 4/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 245s 814ms/step - accuracy: 0.5960 - loss: 1.0387 - val_accuracy: 0.2600 - val_loss: 2.3651
# Epoch 5/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 247s 821ms/step - accuracy: 0.6157 - loss: 0.9991 - val_accuracy: 0.5000 - val_loss: 1.2423
# Epoch 6/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 248s 825ms/step - accuracy: 0.6422 - loss: 0.9443 - val_accuracy: 0.8050 - val_loss: 0.7406
# Epoch 7/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 246s 817ms/step - accuracy: 0.6613 - loss: 0.8895 - val_accuracy: 0.7600 - val_loss: 0.7566
# Epoch 8/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 248s 825ms/step - accuracy: 0.6818 - loss: 0.8375 - val_accuracy: 0.8600 - val_loss: 0.5617
# Epoch 9/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 250s 829ms/step - accuracy: 0.6983 - loss: 0.7917 - val_accuracy: 0.8900 - val_loss: 0.4326
# Epoch 10/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 249s 826ms/step - accuracy: 0.7269 - loss: 0.7366 - val_accuracy: 0.8050 - val_loss: 0.6011
# Epoch 11/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 288s 957ms/step - accuracy: 0.7390 - loss: 0.6822 - val_accuracy: 0.7100 - val_loss: 0.7787
# Epoch 12/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 292s 969ms/step - accuracy: 0.7650 - loss: 0.6374 - val_accuracy: 0.7200 - val_loss: 0.7196
# Epoch 13/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 296s 984ms/step - accuracy: 0.7795 - loss: 0.6208 - val_accuracy: 0.8800 - val_loss: 0.3216
# Epoch 14/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 284s 943ms/step - accuracy: 0.7864 - loss: 0.5594 - val_accuracy: 0.9400 - val_loss: 0.1941
# Epoch 15/15
# 301/301 ━━━━━━━━━━━━━━━━━━━━ 285s 946ms/step - accuracy: 0.7979 - loss: 0.5332 - val_accuracy: 0.9350 - val_loss: 0.2219

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(loc="upper right")

plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(loc="upper left")

plt.tight_layout()
plt.subplots_adjust(top=1.0, bottom=0.0, right=0.95, left=0.0, hspace=0.25, wspace=0.35)
plt.show()

# %%
model.save('Voice_Emotion_Detector\ser_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
